# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3084, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'of', 'term', 'as', 'originated']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.864486
# Nearest to they: naughton, subdue, preserving, receptor, soho, slider, sen, dim,
# Nearest to and: earnings, publishing, flo, dismantled, hazing, fireplace, hash, constitution,
# Nearest to people: slugging, sutras, southwest, barrows, emilia, factions, lictors, suva,
# Nearest to years: awakens, dubh, ascend, yoko, strickland, riverfront, purim, hogshead,
# Nearest to b: perfect, peggy, grammys, timeout, expecting, chants, colonizing, albrecht,
# Nearest to history: mindful, approximated, raises, overture, ordinated, isometry, ces, juggling,
# Nearest to are: yoshi, greenman, unreliable, tutored, catullus, alba, delivered, cheka,
# Nearest to of: salmon, choke, weaning, airships, realign, asclepius, election, haram,
# Nearest to known: depress, phoneme, rocketry, psychiatric, informed, worshipping, wargames, circumference,
# Nearest to up: ludo, constituted, infectors, corners, macromolecules, elbridge, ern, cyclopes,
# Nearest to time: slapstick, floors, goes, mayfield, buddhahood, disregard, battle, coordinating,
# Nearest to this: wandering, epidemic, gustaf, decrement, registers, snippets, cellini, kessler,
# Nearest to had: cetera, lekhanya, duly, pole, lantern, schleswig, ewes, bolo,
# Nearest to was: vitellius, relevance, pseudorandom, boswell, ridicule, maude, depose, handicap,
# Nearest to were: deal, capillaries, specialises, ably, buckingham, jstor, prevented, bremer,
# Nearest to when: ambiguities, chains, nyu, latour, dahalo, nakano, statism, paving,
# Average loss at step 2000: 4.373711
# Average loss at step 4000: 3.867157
# Average loss at step 6000: 3.783003
# Average loss at step 8000: 3.696385
# Average loss at step 10000: 3.619327
# Nearest to they: he, we, it, edvac, notebooks, wail, not, who,
# Nearest to and: or, of, s, mideast, d, but, who, pratchett,
# Nearest to people: barrows, species, bowen, shareware, southwest, qq, coughlin, micronation,
# Nearest to years: dubh, ascend, puranas, spectacular, yoko, escapades, abandonment, zinc,
# Nearest to b: d, perfect, timeout, prostrate, june, peggy, iga, flammable,
# Nearest to history: raises, mindful, exports, operettas, restricting, approximated, visigoths, imaginations,
# Nearest to are: were, is, carpathians, have, but, psalter, sotho, tripartite,
# Nearest to of: in, and, schoolhouse, pomegranate, sodom, offshore, realign, tobruk,
# Nearest to known: worshipping, autumnal, peaked, depress, rocketry, wargames, ditko, rtiges,
# Nearest to up: infectors, constituted, macromolecules, imprint, ludo, elbridge, munster, travelled,
# Nearest to time: battle, swf, refuge, disregard, zimmermann, celebrating, disagree, hussein,
# Nearest to this: it, the, which, that, still, entrance, skirts, midway,
# Nearest to had: has, was, have, cetera, eases, eos, by, oberlin,
# Nearest to was: is, had, has, were, by, be, kombinate, structured,
# Nearest to were: are, was, have, dhimmis, oberlin, mead, tonnes, wands,
# Nearest to when: before, chains, nyu, following, polar, ambiguities, parallel, dahalo,
# Average loss at step 12000: 3.607245
# Average loss at step 14000: 3.570032
# Average loss at step 16000: 3.407701
# Average loss at step 18000: 3.452089
# Average loss at step 20000: 3.542016
# Nearest to they: he, we, there, it, who, notebooks, you, edvac,
# Nearest to and: or, but, in, among, agp, at, militaristic, which,
# Nearest to people: bowen, someone, species, barrows, clarinetist, feistel, worth, composes,
# Nearest to years: ascend, archeologist, puranas, abandonment, cases, opus, dubh, overstated,
# Nearest to b: d, timeout, iga, press, flammable, june, stephen, perfect,
# Nearest to history: raises, manga, mindful, plaster, operettas, output, restricting, worst,
# Nearest to are: were, is, have, but, unreliable, was, sotho, be,
# Nearest to of: for, soils, hesychastic, cornerback, panza, aurelian, phonemic, disappearing,
# Nearest to known: used, worshipping, peaked, autumnal, such, ditko, wargames, depress,
# Nearest to up: infectors, shatila, travelled, gacy, constituted, utterance, jura, out,
# Nearest to time: battle, swf, hussein, mahabharata, endymion, anticipated, year, disagree,
# Nearest to this: it, which, the, brides, tierney, midway, that, its,
# Nearest to had: has, have, was, were, cetera, eos, oberlin, destructor,
# Nearest to was: is, were, has, had, became, be, hailed, tunnel,
# Nearest to were: are, was, had, have, is, be, aan, dhimmis,
# Nearest to when: before, following, if, nyu, elucidation, polar, wholesale, captured,
# Average loss at step 22000: 3.504504
# Average loss at step 24000: 3.495963
# Average loss at step 26000: 3.482279
# Average loss at step 28000: 3.480288
# Average loss at step 30000: 3.503446
# Nearest to they: we, there, he, who, you, it, edvac, these,
# Nearest to and: or, but, rask, amphibians, oscars, who, in, eel,
# Nearest to people: someone, bowen, species, barrows, codes, faerie, christians, navel,
# Nearest to years: puranas, ascend, days, year, ordain, opus, gardner, months,
# Nearest to b: d, iga, flammable, timeout, stephen, press, june, sunny,
# Nearest to history: raises, calvino, plaster, manga, suppl, approving, mainstream, worst,
# Nearest to are: were, have, is, include, be, freely, these, those,
# Nearest to of: in, for, schoolhouse, from, braid, soils, portfolio, outsider,
# Nearest to known: used, worshipping, well, such, designed, peaked, correspondents, responsible,
# Nearest to up: infectors, him, them, out, shatila, ifbb, away, burgundian,
# Nearest to time: year, battle, swf, refuge, turkey, anticipated, disagree, supp,
# Nearest to this: which, it, that, usually, twiggy, itself, what, manometer,
# Nearest to had: has, have, was, were, cetera, oberlin, get, eos,
# Nearest to was: is, were, has, had, became, been, does, be,
# Nearest to were: are, was, have, had, by, dhimmis, while, been,
# Nearest to when: before, if, during, where, after, though, following, while,
# Average loss at step 32000: 3.499529
# Average loss at step 34000: 3.499444
# Average loss at step 36000: 3.453934
# Average loss at step 38000: 3.298553
# Average loss at step 40000: 3.432052
# Nearest to they: we, he, you, there, it, who, edvac, these,
# Nearest to and: or, but, in, gary, solitude, reoccupied, judd, xli,
# Nearest to people: someone, faerie, bowen, species, barrows, hyphens, men, christians,
# Nearest to years: days, months, times, year, opus, gardner, overstated, puranas,
# Nearest to b: d, f, c, stephen, UNK, iga, flammable, peggy,
# Nearest to history: plaster, manga, list, life, suppl, raises, community, approving,
# Nearest to are: were, have, is, be, but, including, coven, include,
# Nearest to of: in, ecclesia, eisner, aurelian, for, soils, disappearing, snowman,
# Nearest to known: used, worshipping, well, peaked, such, responsible, designed, interpreted,
# Nearest to up: out, infectors, him, them, travelled, away, eta, ifbb,
# Nearest to time: year, swf, period, way, battle, hussein, suprema, refuge,
# Nearest to this: which, it, the, that, twiggy, any, moussa, manometer,
# Nearest to had: has, have, was, were, solicited, cetera, having, destructor,
# Nearest to was: is, were, had, became, has, been, be, when,
# Nearest to were: are, was, have, had, while, be, dhimmis, many,
# Nearest to when: before, if, while, where, after, during, though, but,
# Average loss at step 42000: 3.431701
# Average loss at step 44000: 3.456825
# Average loss at step 46000: 3.451359
# Average loss at step 48000: 3.359647
# Average loss at step 50000: 3.386669
# Nearest to they: we, he, there, you, it, she, notebooks, these,
# Nearest to and: or, but, of, scanner, than, by, while, including,
# Nearest to people: someone, men, bowen, children, navel, hyphens, students, women,
# Nearest to years: days, times, months, year, opus, cases, ordain, archeologist,
# Nearest to b: d, f, c, iga, p, flammable, coaster, montfort,
# Nearest to history: manga, cloaca, community, raises, disarming, apparatus, lune, list,
# Nearest to are: were, is, have, be, these, including, include, sotho,
# Nearest to of: and, in, panza, collaborators, pontificia, ortho, notations, including,
# Nearest to known: used, such, peaked, well, worshipping, responsible, possible, called,
# Nearest to up: out, them, off, infectors, him, away, back, humorously,
# Nearest to time: year, way, day, period, kareem, illegality, swf, suprema,
# Nearest to this: which, it, the, that, twiggy, he, encyclopedia, hittites,
# Nearest to had: has, have, was, were, having, glycosylation, solicited, since,
# Nearest to was: is, were, became, has, had, by, be, been,
# Nearest to were: are, was, have, be, had, those, being, been,
# Nearest to when: if, before, while, where, after, during, though, but,
# Average loss at step 52000: 3.438132
# Average loss at step 54000: 3.428455
# Average loss at step 56000: 3.435825
# Average loss at step 58000: 3.396943
# Average loss at step 60000: 3.397887
# Nearest to they: we, there, you, he, she, it, these, i,
# Nearest to and: or, but, than, including, nephite, aurora, loader, latour,
# Nearest to people: someone, men, students, women, bowen, individuals, species, scientists,
# Nearest to years: days, times, months, year, decades, opus, cases, ordain,
# Nearest to b: d, f, x, c, k, m, h, p,
# Nearest to history: economy, list, disarming, suppl, cloaca, collection, manga, apparatus,
# Nearest to are: were, is, including, have, these, those, sotho, be,
# Nearest to of: for, in, snowman, panza, same, like, following, aurelian,
# Nearest to known: used, peaked, such, well, responsible, possible, opposed, called,
# Nearest to up: out, them, him, off, infectors, away, travelled, galley,
# Nearest to time: year, period, way, truetype, limit, psychoacoustics, scrabble, swf,
# Nearest to this: which, it, that, there, the, some, however, goran,
# Nearest to had: has, have, was, were, having, could, been, glycosylation,
# Nearest to was: is, became, had, were, has, been, be, does,
# Nearest to were: are, was, had, have, including, those, been, be,
# Nearest to when: if, before, after, while, because, although, though, where,
# Average loss at step 62000: 3.240942
# Average loss at step 64000: 3.255446
# Average loss at step 66000: 3.400189
# Average loss at step 68000: 3.395156
# Average loss at step 70000: 3.359019
# Nearest to they: we, he, there, you, it, she, slide, who,
# Nearest to and: or, but, while, which, like, see, however, including,
# Nearest to people: men, women, someone, individuals, students, children, bowen, faerie,
# Nearest to years: days, months, year, times, decades, cases, minutes, centuries,
# Nearest to b: f, d, x, c, h, p, k, multilinear,
# Nearest to history: list, disarming, apparatus, remission, collection, brindle, reserve, remarried,
# Nearest to are: were, is, have, these, including, include, although, those,
# Nearest to of: including, for, snowman, in, intrinsic, charterers, trams, include,
# Nearest to known: used, such, regarded, responsible, peaked, classified, well, seen,
# Nearest to up: out, off, them, infectors, away, him, back, down,
# Nearest to time: year, period, way, wyclif, illegality, fuse, psychoacoustics, scrabble,
# Nearest to this: which, it, the, that, some, goran, another, supranationalism,
# Nearest to had: has, have, was, were, having, glycosylation, never, been,
# Nearest to was: is, were, has, had, became, been, does, although,
# Nearest to were: are, was, have, be, had, including, been, although,
# Nearest to when: if, before, while, where, because, though, however, although,
# Average loss at step 72000: 3.378361
# Average loss at step 74000: 3.347470
# Average loss at step 76000: 3.318002
# Average loss at step 78000: 3.351550
# Average loss at step 80000: 3.376924
# Nearest to they: we, he, there, you, she, it, who, edvac,
# Nearest to and: or, but, while, including, horta, inc, when, cpl,
# Nearest to people: men, someone, women, individuals, students, children, those, bowen,
# Nearest to years: days, months, times, decades, year, centuries, weeks, minutes,
# Nearest to b: d, c, f, k, x, p, multilinear, flammable,
# Nearest to history: list, suppl, collection, juggling, reserve, brindle, etienne, dynamically,
# Nearest to are: were, have, is, include, those, although, including, these,
# Nearest to of: in, entire, including, bfi, cornerback, malinowski, although, pontificia,
# Nearest to known: used, regarded, responsible, classified, called, referred, opposed, peaked,
# Nearest to up: out, off, them, infectors, away, him, down, back,
# Nearest to time: period, year, illegality, layers, thing, transporting, compensate, betting,
# Nearest to this: which, it, the, that, manometer, some, another, what,
# Nearest to had: has, have, were, was, having, did, been, saw,
# Nearest to was: is, became, were, had, has, been, be, although,
# Nearest to were: are, had, was, have, those, including, been, being,
# Nearest to when: before, if, though, after, while, during, although, where,
# Average loss at step 82000: 3.408077
# Average loss at step 84000: 3.412415
# Average loss at step 86000: 3.389525
# Average loss at step 88000: 3.351644
# Average loss at step 90000: 3.365064
# Nearest to they: we, he, there, you, she, it, edvac, but,
# Nearest to and: or, but, while, alves, colliery, including, kaposi, although,
# Nearest to people: men, women, someone, students, children, individuals, man, tian,
# Nearest to years: days, months, decades, year, times, minutes, centuries, weeks,
# Nearest to b: d, f, c, multilinear, k, p, h, tickets,
# Nearest to history: list, brindle, genome, etienne, collection, rips, suppl, disarming,
# Nearest to are: were, is, include, have, although, these, sotho, including,
# Nearest to of: snowman, including, malinowski, for, ortho, in, hadassah, collaborators,
# Nearest to known: used, regarded, such, called, opposed, responsible, seen, possible,
# Nearest to up: out, off, away, them, back, infectors, him, down,
# Nearest to time: period, illegality, year, decade, if, way, goro, suprema,
# Nearest to this: it, which, the, itself, some, similar, any, another,
# Nearest to had: has, have, was, were, having, glycosylation, never, responded,
# Nearest to was: is, had, became, were, been, be, has, being,
# Nearest to were: are, had, was, have, those, while, been, although,
# Nearest to when: before, if, while, after, although, though, where, until,
# Average loss at step 92000: 3.398602
# Average loss at step 94000: 3.258077
# Average loss at step 96000: 3.358400
# Average loss at step 98000: 3.246544
# Average loss at step 100000: 3.355963
# Nearest to they: we, he, there, you, she, it, i, edvac,
# Nearest to and: but, or, however, although, who, including, while, omari,
# Nearest to people: men, someone, children, women, students, individuals, those, scientists,
# Nearest to years: days, months, decades, year, times, minutes, centuries, weeks,
# Nearest to b: d, c, faxes, iga, speculates, flammable, multilinear, swedish,
# Nearest to history: list, suppl, gx, calvino, brindle, collection, genome, etienne,
# Nearest to are: were, although, have, include, those, be, is, these,
# Nearest to of: including, hadassah, in, entire, during, vijayanagara, bfi, and,
# Nearest to known: used, possible, regarded, such, available, opposed, seen, classified,
# Nearest to up: out, off, away, them, infectors, him, galley, down,
# Nearest to time: period, year, way, decade, illegality, wyclif, transporting, thing,
# Nearest to this: which, it, itself, he, another, bankruptcy, some, that,
# Nearest to had: has, have, was, having, would, were, saw, is,
# Nearest to was: is, became, were, had, has, been, being, knicks,
# Nearest to were: are, was, although, have, those, these, including, had,
# Nearest to when: if, while, before, although, after, though, where, during,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
